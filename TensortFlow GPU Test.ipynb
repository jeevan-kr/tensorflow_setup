# %%
import os
import inspect
import tensorflow
print(os.path.dirname(inspect.getfile(tensorflow)))
# Out:
# /home/jeevan/anaconda2/envs/tf2/lib/python2.7/site-packages/tensorflow

# %%
from time import gmtime, strftime
print strftime("%Y-%m-%d %H:%M:%S", gmtime())
# %run /home/jeevan/anaconda2/envs/tf2/lib/python2.7/site-packages/tensorflow/models/image/mnist/convolutional.py
print strftime("%Y-%m-%d %H:%M:%S", gmtime())
# Out:
# 2016-11-07 14:35:03
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting data/train-images-idx3-ubyte.gz
# Extracting data/train-labels-idx1-ubyte.gz
# Extracting data/t10k-images-idx3-ubyte.gz
# Extracting data/t10k-labels-idx1-ubyte.gz
# Initialized!
# Step 0 (epoch 0.00), 10.4 ms
# Minibatch loss: 8.334, learning rate: 0.010000
# Minibatch error: 85.9%
# Validation error: 84.6%
# Step 100 (epoch 0.12), 5.6 ms
# Minibatch loss: 3.254, learning rate: 0.010000
# Minibatch error: 6.2%
# Validation error: 7.7%
# Step 200 (epoch 0.23), 5.4 ms
# Minibatch loss: 3.365, learning rate: 0.010000
# Minibatch error: 9.4%
# Validation error: 4.3%
# Step 300 (epoch 0.35), 5.5 ms
# Minibatch loss: 3.149, learning rate: 0.010000
# Minibatch error: 6.2%
# ...

# %%
# This logs the device to which the tensorflow session is being directed to
# Helps check if GPU is being used
sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))
